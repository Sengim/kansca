# %%
import torch
from pathlib import Path
import os
import hydra
import numpy as np
import matplotlib.pyplot as plt

os.chdir('/workspace')
import src

# %%
def get_cfg(pos):
    with hydra.initialize(config_path="../conf", version_base='1.1'):
        cfg = hydra.compose(
            config_name='config',
            overrides=[
                "model=KAN1h",
                "model.model.width.0=2",
                "model.model.width.1=1",
                "model.model.grid=3",
                "model.train_params.steps=3000",
                "dataset@train=masking_sim",
                "dataset@test=masking_sim",
                "trace_transforms=void",
                "label_transforms=bit_sim",
                f"label_transforms.transforms.0.pos=0",
                f"save_path=/workspace/results/simulation/KAN_All/0",
                "n_attack_traces=2000"
                ]
            )
    return cfg

# %%
def train(cfg):
    device = hydra.utils.instantiate(cfg.device)
    cpu = torch.device('cpu')

    # Dataset
    profiling_dataset = hydra.utils.instantiate(cfg.train.dataset)
    test_dataset = hydra.utils.instantiate(cfg.test.dataset)

    train_dataloader = torch.utils.data.DataLoader(
        profiling_dataset, batch_size=cfg.train.batch_size, shuffle=True
    )
    test_dataloader = torch.utils.data.DataLoader(
        test_dataset, batch_size=cfg.test.batch_size, shuffle=False
    )
    KANds = src.utils.to_KAN_dataset(
        train_dataloader, test_dataloader,
        device=device)

    # Train
    model = hydra.utils.instantiate(cfg.model.model)
    model.load_ckpt(cfg.model_name+'.ckpt', cfg.save_path)
    model = model.to(device)

    # Test
    preds, labels, th = src.utils.make_prediction(
    model, test_dataloader, device)
    preds_class = np.argmax(preds, axis=1)
    accuracy = np.mean(labels == preds_class)
    print('Accuracy: ', accuracy)

    return model, KANds, test_dataset, test_dataloader, device

# %%
cfg = get_cfg(0)
model, KANds, test_dataset, test_dataloader, device = train(cfg)
# Out:
# Accuracy:  0.5363311767578125

# %%
test_inputs = torch.tensor(
    np.array([test_dataset[v][0] for v in range(cfg.n_attack_traces)])).to(device)
_ = model(test_inputs)
model.plot(folder=cfg.save_path+'/plot')
plt.savefig(
    Path(cfg.save_path, f'{cfg.model.name}.png'),
    dpi=300, bbox_inches=0)
src.utils.plot_KAN(cfg, model, 'plot')

# %%
model.fix_symbolic(0,0,0, 'x')
model.fix_symbolic(0,1,0, 'x')
# Out:
# Best value at boundary.
# r2 is 0.9258054494857788
# r2 is 0.9506756067276001
# tensor(0.9507, device='cuda:0')

# %%
_ = model.train(
    KANds,
    **hydra.utils.instantiate(cfg.model.train_params)
    )
# Out:
# train loss: 8.29e-01 | test loss: 8.29e-01 | reg: 5.00e-01 : 100%|█| 3000/3000 [01:48<00:00, 27.77it

# %%
preds, labels, th = src.utils.make_prediction(
    model, test_dataloader, device)

preds_class = np.argmax(preds, axis=1)
accuracy = np.mean(labels == preds_class)
print('Accuracy: ', accuracy)
# Out:
# Accuracy:  0.5310821533203125

# %%
model(KANds['train_input'])
model.plot(folder=cfg.save_path+'/plot_replaced')
plt.savefig(
    Path(cfg.save_path, f'{cfg.model.name}_replaced.png'),
    dpi=300, bbox_inches='tight')
